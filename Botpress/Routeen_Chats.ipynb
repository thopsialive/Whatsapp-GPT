# %% [markdown]
# # Routeen Chat Results

# %% [markdown]
# **Chat 1**
#
# ![Chat1_Bot.png](attachment:Chat1_Bot.png)
#
# The loop can be a bit robotic, especially after the *multiple choice*.

# %% [markdown]
# ![Chat1_1.png](attachment:Chat1_1.png)
#
# Why is the response in bullet point format?

# %% [markdown]
# ![Chat1_2.png](attachment:Chat1_2.png)
#
# Completely ignored my question. Maybe there can be interchangeable words, e.g. "meeting", "schedule", "zoom", "teams", etc.?
#
# Also typing *Yes* instead of answer the mcq works too.
